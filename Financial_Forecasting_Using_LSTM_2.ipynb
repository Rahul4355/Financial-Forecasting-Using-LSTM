# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# 5           1.0
# 6           1.0
# 7           1.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          1.0
# 14          1.0
# 15          1.0
# 16          1.0
# 17          1.0
# 18          1.0
# 19          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] 
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) 
df.set_index('date',drop=True,inplace=True) 
df.head(20)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26
# 2016-06-28  678.97  680.04
# 2016-06-29  683.00  684.11
# 2016-06-30  685.47  692.10
# 2016-07-01  692.20  699.21
# 2016-07-05  696.06  694.49
# 2016-07-06  689.98  697.77
# 2016-07-07  698.08  695.36
# 2016-07-08  699.50  705.63
# 2016-07-11  708.05  715.09
# 2016-07-12  719.12  720.64

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(20)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000
# 2016-06-28  0.004299  0.006356
# 2016-06-29  0.006473  0.008552
# 2016-06-30  0.007805  0.012863
# 2016-07-01  0.011435  0.016700
# 2016-07-05  0.013517  0.014153
# 2016-07-06  0.010238  0.015923
# 2016-07-07  0.014607  0.014622
# 2016-07-08  0.015373  0.020164
# 2016-07-11  0.019985  0.025268
# 2016-07-12  0.025956  0.028262

# %%
training_size = round(len(df) * 0.75) 
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): 
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 50, 50)              │          10,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 2)                   │             102 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,902 (120.71 KB)
#  Trainable params: 30,902 (120.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 0.0107 - mean_absolute_error: 0.0754 - val_loss: 0.0102 - val_mean_absolute_error: 0.0810
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 6.5537e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0043 - val_mean_absolute_error: 0.0516
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.3601e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0032 - val_mean_absolute_error: 0.0434
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.3642e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0046 - val_mean_absolute_error: 0.0533
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.3769e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0037 - val_mean_absolute_error: 0.0464
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 4.1382e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0033 - val_mean_absolute_error: 0.0439
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.1977e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 4.1419e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0038 - val_mean_absolute_error: 0.0476
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.3609e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0065 - val_mean_absolute_error: 0.0666
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.5472e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 3.9123e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0050 - val_mean_absolute_error: 0.0570
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.9062e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 2.9481e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0054 - val_mean_absolute_error: 0.0600
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.1655e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0030 - val_mean_absolute_error: 0.0416
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 3.7827e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.0696e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0051 - val_mean_absolute_error: 0.0584
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 3.9690e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0034 - val_mean_absolute_error: 0.0454
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.0017e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0059 - val_mean_absolute_error: 0.0645
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 3.6334e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 2.8363e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0031 - val_mean_absolute_error: 0.0440
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 3.2252e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.3192e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0026 - val_mean_absolute_error: 0.0392
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 2.6416e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0033 - val_mean_absolute_error: 0.0463
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.9601e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.8313e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0022 - val_mean_absolute_error: 0.0356
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 2.9987e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 2.9977e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0016 - val_mean_absolute_error: 0.0296
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 2.6543e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0023 - val_mean_absolute_error: 0.0364
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 2.7421e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0029 - val_mean_absolute_error: 0.0423
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 2.3128e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0038 - val_mean_absolute_error: 0.0487
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - loss: 2.2699e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0036 - val_mean_absolute_error: 0.0476
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 2.4929e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0025 - val_mean_absolute_error: 0.0379
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 2.1973e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0044 - val_mean_absolute_error: 0.0531
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.5503e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 2.6294e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 2.6112e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0024 - val_mean_absolute_error: 0.0363
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 3.0748e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0022 - val_mean_absolute_error: 0.0358
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.1028e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0039 - val_mean_absolute_error: 0.0506
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 2.3418e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0026 - val_mean_absolute_error: 0.0396
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 2.2121e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0027 - val_mean_absolute_error: 0.0405
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.2624e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 2.0542e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0032 - val_mean_absolute_error: 0.0451
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 2.1074e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 2.1590e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0025 - val_mean_absolute_error: 0.0385
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.9248e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0020 - val_mean_absolute_error: 0.0338
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.1134e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0031 - val_mean_absolute_error: 0.0441
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 2.0451e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0018 - val_mean_absolute_error: 0.0319
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.2320e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0033 - val_mean_absolute_error: 0.0457
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 1.8330e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0021 - val_mean_absolute_error: 0.0352
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.0654e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0031 - val_mean_absolute_error: 0.0428
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.9967e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.8610e-04 - mean_absolute_error: 0.0100 - val_loss: 9.1603e-04 - val_mean_absolute_error: 0.0220
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.0501e-04 - mean_absolute_error: 0.0104 - val_loss: 7.7244e-04 - val_mean_absolute_error: 0.0203
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 2.2374e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 1.8581e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 1.7194e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0022 - val_mean_absolute_error: 0.0367
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.6518e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0017 - val_mean_absolute_error: 0.0302
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.9370e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0016 - val_mean_absolute_error: 0.0296
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.8292e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.6471e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0025 - val_mean_absolute_error: 0.0398
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.7595e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 1.5301e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 1.6226e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0022 - val_mean_absolute_error: 0.0368
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.5766e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0021 - val_mean_absolute_error: 0.0352
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.5807e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0020 - val_mean_absolute_error: 0.0347
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.4935e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.7959e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 1.5192e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 1.5412e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.6248e-04 - mean_absolute_error: 0.0093 - val_loss: 9.8278e-04 - val_mean_absolute_error: 0.0224
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.6514e-04 - mean_absolute_error: 0.0094 - val_loss: 7.7455e-04 - val_mean_absolute_error: 0.0203
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.7812e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0017 - val_mean_absolute_error: 0.0310
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 1.4710e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0018 - val_mean_absolute_error: 0.0326
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.4668e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0015 - val_mean_absolute_error: 0.0285
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 1.6820e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0037 - val_mean_absolute_error: 0.0499
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 1.4879e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0019 - val_mean_absolute_error: 0.0324
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.4789e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0022 - val_mean_absolute_error: 0.0359
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 1.3581e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0016 - val_mean_absolute_error: 0.0295
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.3636e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 1.4269e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0037 - val_mean_absolute_error: 0.0502
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 1.4292e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.4155e-04 - mean_absolute_error: 0.0084 - val_loss: 8.4681e-04 - val_mean_absolute_error: 0.0210
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 1.3192e-04 - mean_absolute_error: 0.0083 - val_loss: 8.0299e-04 - val_mean_absolute_error: 0.0204
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 1.2092e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 1.2542e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 1.2205e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0020 - val_mean_absolute_error: 0.0369
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 1.4372e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.5166e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0021 - val_mean_absolute_error: 0.0373
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.2464e-04 - mean_absolute_error: 0.0083 - val_loss: 9.7703e-04 - val_mean_absolute_error: 0.0233
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.0760e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0017 - val_mean_absolute_error: 0.0315
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.2429e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0342
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 1.2433e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 1.2537e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 1.0372e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1.1242e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 1.2009e-04 - mean_absolute_error: 0.0079 - val_loss: 4.8830e-04 - val_mean_absolute_error: 0.0159
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 1.5430e-04 - mean_absolute_error: 0.0089 - val_loss: 8.0012e-04 - val_mean_absolute_error: 0.0211
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 1.0843e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.2268e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.0919e-04 - mean_absolute_error: 0.0074 - val_loss: 8.2834e-04 - val_mean_absolute_error: 0.0211

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# array([[0.40453538, 0.4055922 ],
#        [0.40441036, 0.40544206],
#        [0.40043676, 0.40156406],
#        [0.4033423 , 0.40440062],
#        [0.40686947, 0.40786523]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1420.9762, 1419.9603],
#        [1420.7445, 1419.682 ],
#        [1413.3777, 1412.4948],
#        [1418.7644, 1417.7518],
#        [1425.3035, 1424.173 ]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                      pd.DataFrame(test_inverse_predicted,
                                   columns=['open_predicted','close_predicted'],
                                                         index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1420.976196      1419.960327
# 2020-05-28  1396.86  1416.73     1420.744507      1419.682007
# 2020-05-29  1416.94  1428.92     1413.377686      1412.494751
# 2020-06-01  1418.39  1431.82     1418.764404      1417.751831
# 2020-06-02  1430.55  1439.22     1425.303467      1424.172974

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
new_data = pd.DataFrame(index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))

df_merge = pd.concat([df_merge, new_data])

selected_date_range = df_merge['2021-06-09':'2021-06-28']
print(selected_date_range)
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2419.567627      2378.780518
# 2021-06-10  2494.01  2521.60     2424.242920      2382.876221
# 2021-06-11  2524.92  2513.93     2434.898438      2393.179932
# 2021-06-11      NaN      NaN             NaN              NaN
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN
# 2021-06-17      NaN      NaN             NaN              NaN
# 2021-06-18      NaN      NaN             NaN              NaN
# 2021-06-19      NaN      NaN             NaN              NaN
# 2021-06-20      NaN      NaN             NaN              NaN
# 2021-06-21      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-03-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-03-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %%
actual_prices = np.array([100, 105, 110, 115, 120, 125]) 

predictions = np.array([98, 102, 108, 114, 118, 123])  

plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions, label='Predicted Prices', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()

# %%
close_prices = df_merge['close'].values.reshape(-1, 1)  

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
close_prices_scaled = scaler.fit_transform(close_prices)

# %%
close_prices = df_merge['close'].values.reshape(-1, 1)  
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close_prices = scaler.fit_transform(close_prices)

# %%
def create_lstm_dataset(data, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps), 0])
        y.append(data[i + time_steps, 0])
    return np.array(X), np.array(y)

# Create LSTM dataset
X, y = create_lstm_dataset(scaled_close_prices, time_steps=10)

# %%
# Train-Test Split
split_ratio = 0.8  # 80% for training, 20% for testing

split_index = int(len(X) * split_ratio)
X_train, X_test, y_train, y_test = X[:split_index], X[split_index:], y[:split_index], y[split_index:]

# %%
# LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs = 50 
batch_size = 32  

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Training the LSTM model
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

# Plotting training loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Ploting training accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.0107 - loss: 0.0998
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0036 - loss: 0.0150
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0026 - loss: 0.0154
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0090
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0036 - loss: 0.0058
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0039
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0036 - loss: 0.0035
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0026 - loss: 0.0031
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0012 - loss: 0.0031
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0036 - loss: 0.0030
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0049 - loss: 0.0025
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0018 - loss: 0.0029
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0068 - loss: 0.0029
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0018 - loss: 0.0027
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0026 - loss: 0.0030
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0018 - loss: 0.0027
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0026 - loss: 0.0029
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0026
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0049 - loss: 0.0031
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0036 - loss: 0.0031
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0018 - loss: 0.0027
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0026 - loss: 0.0029
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0107 - loss: 0.0029
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0107 - loss: 0.0028
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0018 - loss: 0.0025
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0027
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0028
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0068 - loss: 0.0025
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0012 - loss: 0.0028
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0012 - loss: 0.0024
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0018 - loss: 0.0029
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0036 - loss: 0.0025
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0036 - loss: 0.0026
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0036 - loss: 0.0027
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0049 - loss: 0.0029
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0049 - loss: 0.0028
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0068 - loss: 0.0024
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0018 - loss: 0.0024
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0036 - loss: 0.0024
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0018 - loss: 0.0023
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0036 - loss: 0.0023
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0012 - loss: 0.0024
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0012 - loss: 0.0026
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0018 - loss: 0.0027
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0018 - loss: 0.0028
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0049 - loss: 0.0026
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0107 - loss: 0.0024
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0049 - loss: 0.0022
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0026 - loss: 0.0024
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0026 - loss: 0.0025

# %%
predicted_prices = model.predict(X_test)
predicted_prices = np.nan_to_num(predicted_prices)  
predicted_prices = scaler.inverse_transform(predicted_prices)  

from sklearn.metrics import mean_squared_error

y_test = np.nan_to_num(y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
X_test = scaler.inverse_transform(X_test.reshape(-1, 1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions, label='Predicted Prices', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual_prices[-20:], label='Actual Prices', color='blue', marker='o')
predicted_future_prices = model.predict(X[-20:])
predicted_future_prices = scaler.inverse_transform(predicted_future_prices)
plt.plot(predicted_future_prices, label='Predicted Prices', color='red', marker='o')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction for Next 20 Days')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
